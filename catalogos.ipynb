# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# Ahora que tenemos los catálogos de cada uno de los distintos archivos guardados, necesitamos homogeneizarlos en función de las cuentas principales y las coincidencias

# %%
catalogo = pd.read_excel("datos/catalogos.xlsx", index_col=0)

# %% [markdown]
# Primero definimos las cuentas que queremos normalizar:
# ### Estado de situación financiera
# - Activo total
#     - Activo corriente
#     - Activo no corriente
# - Pasivo total
#     - Pasivo corriente
#     - Pasivo no corriente
# - Patrimonio neto
#     - Capital
#     - Ganancia neta del periodo
#     - Pérdida neta del periodo
#
# ### Estado de resultados integral
# - Ingresos
#     - Ingreso operacional
#     - Ingreso no operacional
#     - Otros ingresos
# - Egresos
#     - Costos de producción
#         - Mano de obra
#     - Gastos
# - Utilidad bruta
# - Utilidad antes de impuestos
# - Impuesto a la renta causado
# - Utilidad neta

# %%
catalogo
# Out:
#                                     catalogo_2000_1  \
# 0                                     Caja - Bancos
# 1                Inversiones financieras temporales
# 2        Cuentas y documentos por cobrar (clientes)
# 3                 (-) Provision cuentas incobrables
# 4                          Otras cuentas por cobrar
# ..                                              ...
# 120  Utilidad (Perdida) despues del Imp. a la Renta
# 121                                   (-) Anticipos
# 122                    (-) Retenciones en la Fuente
# 123                                     Total Renta
# 124                             Total Saldo a Favor
#
#                                 catalogo_2000_2  \
# 0                                 Caja - Bancos
# 1            Inversiones financieras temporales
# 2    Cuentas y documentos por cobrar (clientes)
# 3             (-) Provision cuentas incobrables
# 4                      Otras cuentas por cobrar
# ...
